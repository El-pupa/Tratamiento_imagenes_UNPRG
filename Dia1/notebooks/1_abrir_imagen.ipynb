# %% [markdown]
# # Tratamiento de imágenes

# %% [markdown]
# ### Importar librerias

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Abrir imagen usando opencv

# %%
# %pwd
# Out:
# '/home/stevend/Documents/Notebooks/Dia1/notebooks'

# %%
path = "/home/stevend/Documents/Notebooks/Dia1/imagenes/dedo_gatillo.png"

img = cv2.imread(path,cv2.IMREAD_COLOR)

# %% [markdown]
# ## Mostrar imagen en opencv

# %%
cv2.imshow("Dedo Gatillo", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/stevend/anaconda3/lib/python3.11/site-packages/cv2/qt/plugins"
# QObject::moveToThread: Current thread (0x328cd20) is not the object's thread (0x3297260).
# Cannot move to target thread (0x328cd20)
#
# QObject::moveToThread: Current thread (0x328cd20) is not the object's thread (0x3297260).
# Cannot move to target thread (0x328cd20)
#
# QObject::moveToThread: Current thread (0x328cd20) is not the object's thread (0x3297260).
# Cannot move to target thread (0x328cd20)
#
# QObject::moveToThread: Current thread (0x328cd20) is not the object's thread (0x3297260).
# Cannot move to target thread (0x328cd20)
#
# QObject::moveToThread: Current thread (0x328cd20) is not the object's thread (0x3297260).
# Cannot move to target thread (0x328cd20)
#
# QObject::moveToThread: Current thread (0x328cd20) is not the object's thread (0x3297260).
# Cannot move to target thread (0x328cd20)
#
# ...

# %% [markdown]
# ## Mostrar imagen en matplotlib

# %%
plt.imshow(img)
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Verificar si la imagen es RGB o BGR

# %% [markdown]
# plt.imshow, grafica considerando que la imagen de entrada es RGB, apesar que no sea. La mejor forma de saber si es BGR o RGB es graficandola en su totalidad.

# %%
img_aux = img.copy()
img_aux[:,:,0] = 0
img_aux[:,:,1] = 0


plt.imshow(img_aux)
plt.show()

# %%
plt.imshow(img)

# %% [markdown]
# ## Convertir BGR a RGB

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)

# %%
img_rgb.shape
# Out:
# (1150, 900, 3)
